# %%
import pyecharts
from pyecharts import Bar
from pyecharts import online
# online()
import json
import codecs
#path = 'D:\\11\\11.json'
path = '.\\11result.json'
with open(path, 'r', encoding='utf-8') as f:
    temp = json.load(f)
    list = []
    list = temp
temp = []
for i in list:
    temp.append(i)

print(len(temp))
for i in temp:
    try:
        i['nums'] = int(i['nums'])
    except:
        print('error')
#temp.sort(key = lambda x:x["nums"])
#temp.reverse()

dic_n_new = {} #新词
dic_nr = {} # 人名
dic_ns = {} # 地名
dic_nt = {} # 机构团体名
dic_nz = {} # 其它专名

res_n_new = [] #新词
res_nr = [] # 人名
res_ns = [] # 地名
res_nt = [] # 机构团体名
res_nz = [] # 其它专名
for i in temp:
    try:
        if i['cates'] == 'n_new': 
            if i['words'] in dic_n_new:
                dic_n_new[i['words']] = dic_n_new[i['words']] + i['nums']
            else:
                dic_n_new[i['words']] = i['nums']
        if i['cates'] == 'nr':
            if i['words'] in dic_nr:
                dic_nr[i['words']] = dic_nr[i['words']] + i['nums']
            else:
                dic_nr[i['words']] = i['nums']
        if i['cates'] == 'ns':
            if i['words'] in dic_ns:
                dic_ns[i['words']] = dic_ns[i['words']] + i['nums']
            else:
                dic_ns[i['words']] = i['nums']
        if i['cates'] == 'nt':
            if i['words'] in dic_nt:
                dic_nt[i['words']] = dic_nt[i['words']] + i['nums']
            else:
                dic_nt[i['words']] = i['nums']
        if i['cates'] == 'nz':
            if i['words'] in dic_nz:
                dic_nz[i['words']] = dic_nz[i['words']] + i['nums']
            else:
                dic_nz[i['words']] = i['nums']       
    except:
        #print("eroor")
        pass

#处理各个词性的数据，最后逆序排列
def deal(res, dic):
    res.clear()
    c = {}
    for key in dic:
        c['words'] = key
        c['nums'] = dic[key]
        res.append(c)
        c = {}
    res.sort(key = lambda x:x['nums'])
    res.reverse() 

# 输出list数据
def output(res, num = 40):
    for i in res[:num]:
        print(i)
# Out:
# 188345
# error
# error

# %%
deal(res_n_new, dic_n_new) #进行数据储存
output(res_n_new, 30) #数据输出
attr_n_new = []
value_n_new = []
for n_new in res_n_new[4:30]:
    attr_n_new.append(n_new['words'])
    value_n_new.append(n_new['nums'])
bar = Bar("2017年11月份名词记", "2017年11月出现频率最高的名词")
bar.add("主视图", attr_n_new, value_n_new, xaxis_interval=0, xaxis_rotate=30, yaxis_rotate=30)
# bar
# Out:
# {'words': '微信', 'nums': 832}
# {'words': '告诉记者', 'nums': 815}
# {'words': '犯罪嫌疑人', 'nums': 810}
# {'words': '公安机关', 'nums': 493}
# {'words': '双11', 'nums': 361}
# {'words': '共享单车', 'nums': 348}
# {'words': '安全隐患', 'nums': 310}
# {'words': '野生动物', 'nums': 282}
# {'words': '微博', 'nums': 268}
# {'words': '主播', 'nums': 227}
# {'words': '客服', 'nums': 226}
# {'words': '工作人员', 'nums': 205}
# {'words': '淘宝', 'nums': 189}
# {'words': '公民个人信息', 'nums': 172}
# {'words': '网购', 'nums': 167}
# {'words': '精准', 'nums': 153}
# {'words': '携程亲子园', 'nums': 153}
# {'words': '导盲犬', 'nums': 150}
# {'words': '巡察', 'nums': 147}
# {'words': '搜救', 'nums': 146}
# {'words': '王先生', 'nums': 146}
# {'words': '判处有期徒刑', 'nums': 143}
# {'words': '检察机关', 'nums': 142}
# {'words': '中国青年报', 'nums': 137}
# {'words': '刑事拘留', 'nums': 129}
# {'words': '个人信息', 'nums': 124}
# {'words': '专项行动', 'nums': 124}
# {'words': '筛查', 'nums': 119}
# {'words': '办案民警', 'nums': 114}
# {'words': '碰瓷', 'nums': 114}

# %% [markdown]
# ![alt text](http://img.blog.csdn.net/20180223211134624?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvc3R5OTQ1/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "Logo Title Text 1")

# %%
from pyecharts import WordCloud

deal(res_nr, dic_nr)
output(res_nr)

attr_nr = []
value_nr = []
for nr in res_nr:
    attr_nr.append(nr['words'])
    value_nr.append(nr['nums'])

wordcloud = WordCloud("2017年11月份人名记", "2017年11月出现频率最高的人名",width=900, height=620, title_pos="center")
wordcloud.add("人名", attr_nr[:40], value_nr[:40], word_size_range=[20, 120], shape='star')
# wordcloud
# Out:
# {'words': '王某', 'nums': 396}
# {'words': '李某', 'nums': 350}
# {'words': '张某', 'nums': 321}
# {'words': '陈某', 'nums': 250}
# {'words': '刘鑫', 'nums': 206}
# {'words': '刘某', 'nums': 194}
# {'words': '江歌', 'nums': 189}
# {'words': '朱晓东', 'nums': 137}
# {'words': '李绪义', 'nums': 128}
# {'words': '杨欢', 'nums': 102}
# {'words': '赵勇', 'nums': 100}
# {'words': '赵某', 'nums': 91}
# {'words': '陈世峰', 'nums': 90}
# {'words': '黄淑芬', 'nums': 85}
# {'words': '徐利', 'nums': 81}
# {'words': '曹伊珂', 'nums': 70}
# {'words': '林某', 'nums': 69}
# {'words': '林智双', 'nums': 68}
# {'words': '朱某', 'nums': 67}
# {'words': '何某', 'nums': 66}
# {'words': '彭宇华', 'nums': 64}
# {'words': '张林苍', 'nums': 62}
# {'words': '老赖', 'nums': 61}
# {'words': '徐孟南', 'nums': 60}
# {'words': '杨晓飞', 'nums': 59}
# {'words': '段勇', 'nums': 58}
# {'words': '孙某', 'nums': 55}
# {'words': '吴某', 'nums': 55}
# {'words': '胡某', 'nums': 54}
# {'words': '郝如翔', 'nums': 51}
# {'words': '孟凡芹', 'nums': 51}
# {'words': '李伟', 'nums': 49}
# {'words': '韦某', 'nums': 49}
# {'words': '陈燕', 'nums': 48}
# {'words': '黄云彪', 'nums': 48}
# {'words': '阿伟', 'nums': 48}
# {'words': '张志菊', 'nums': 47}
# {'words': '杨莉', 'nums': 47}
# {'words': '黄某', 'nums': 47}
# {'words': '周义强', 'nums': 45}

# %% [markdown]
# ![词云](https://img-blog.csdn.net/20180401213031803?watermark/2/text/aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L3N0eTk0NQ==/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "2017年11月出现频率最高的人名")

# %%
from pyecharts import Geo
deal(res_ns, dic_ns)
# output(res_ns)
data = []
data.clear()
for ns in res_ns:
    tupl = (ns["words"], ns["nums"])
    data.append(tupl)
   
geo = Geo("全国主要城市11月份出现频率", "data from chinanews", title_color="#fff", title_pos="center",
width=800, height=600, background_color='#434a59')
attr, value = geo.cast(data)

geo.add("", attr, value, visual_range=[0, 3000], visual_text_color="#fff",
        symbol_size=15, is_visualmap=True)
# geo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6237765281c> in <module>
#       1 from pyecharts import Geo
# ----> 2 deal(res_ns, dic_ns)
#       3 # output(res_ns)
#       4 data = []
#       5 data.clear()
#
# NameError: name 'deal' is not defined

# %% [markdown]
# ![地图](http://img.blog.csdn.net/20180223211153842?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvc3R5OTQ1/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "全国主要城市11月份出现频率")

# %%
from pyecharts import Map

attr_ns = []
value_ns = []
for ns in res_ns:
    attr_ns.append(ns['words'])
    value_ns.append(ns['nums'])
map = Map("11月份各省市新闻出现频率", width=800, height=600)
map.add("", attr_ns, value_ns, maptype='china', is_visualmap=True, visual_text_color='#000', is_label_show=True)
# map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="64e9e52ce2b04018a41aede8019616ca" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_64e9e52ce2b04018a41aede8019616ca = echarts.init(document.getElementById('64e9e52ce2b04018a41aede8019616ca'), 'light', {renderer: 'canvas'});
#
# var option_64e9e52ce2b04018a41aede8019616ca = {
#     "title": [
#         {
#             "text": "11\u6708\u4efd\u5404\u7701\u5e02\u65b0\u95fb\u51fa\u73b0\u9891\u7387",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 627517,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 3360
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2255
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 876
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 745
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 607
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 320
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 280
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 230
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 191
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 183
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 172
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 167
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 152
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 123
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u957f\u57ce",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6843\u6c5f\u53bf",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u4eac\u4e1c",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u4e3d\u6c34",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u957f\u6c5f",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 59
#                 },
#                 {
#                     "name": "\u4e5d\u5be8\u6c9f",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6c38\u5b9a\u6cb3",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9ec4\u77f3",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u57ce\u968d\u5e99",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u6d77\u5357\u7701",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u9646\u4e30",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u5

# %% [markdown]
# ![地图](http://img.blog.csdn.net/20180223211125903?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvc3R5OTQ1/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "11月份各省市新闻出现频率")

# %%
from pyecharts import Pie
deal(res_nt, dic_nt)
output(res_nt)
attr_nt = []
value_nt = []
for nt in res_nt:
    attr_nt.append(nt['words'])
    value_nt.append(nt['nums'])
pie = Pie("11月份出现的高频机构", title_pos='right')
pie.add("", attr_nt[2:15], value_nt[2:15], radius=[40, 75], label_text_color=None, is_label_show=True,
        legend_orient='vertical', legend_pos='left')
# pie
# Out:
# {'words': '中新网', 'nums': 1142}
# {'words': '新华社', 'nums': 228}
# {'words': '公安部', 'nums': 212}
# {'words': '人民检察院', 'nums': 87}
# {'words': '国务院', 'nums': 62}
# {'words': '清华大学', 'nums': 61}
# {'words': '教育部', 'nums': 52}
# {'words': '最高人民法院', 'nums': 30}
# {'words': '中央气象台', 'nums': 28}
# {'words': '北京大学', 'nums': 25}
# {'words': '联合国', 'nums': 23}
# {'words': '气象局', 'nums': 15}
# {'words': '中央纪委', 'nums': 13}
# {'words': '新华网', 'nums': 10}
# {'words': '党中央', 'nums': 9}
# {'words': '中国共产党', 'nums': 9}
# {'words': '中央电视台', 'nums': 8}
# {'words': '新冶钢', 'nums': 7}
# {'words': '林业局', 'nums': 7}
# {'words': '中国红十字会', 'nums': 6}
# {'words': '财政局', 'nums': 6}
# {'words': '中国证监会', 'nums': 6}
# {'words': '中国人民银行', 'nums': 6}
# {'words': '中国移动', 'nums': 5}
# {'words': '农业部', 'nums': 5}
# {'words': '司法部', 'nums': 4}
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="65fded811ed14a37828af630d92411aa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_65fded811ed14a37828af630d92411aa = echarts.init(document.getElementById('65fded811ed14a37828af630d92411aa'), 'light', {renderer: 'canvas'});
#
# var option_65fded811ed14a37828af630d92411aa = {
#     "title": [
#         {
#             "text": "11\u6708\u4efd\u51fa\u73b0\u7684\u9ad8\u9891\u673a\u6784",
#             "left": "right",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4741472,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u516c\u5b89\u90e8",
#                     "value": 212
#                 },
#                 {
#                     "name": "\u4eba\u6c11\u68c0\u5bdf\u9662",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u56fd\u52a1\u9662",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u6e05\u534e\u5927\u5b66",
#                     "value": 61
#                 },
#                 {
#                     "name": "\u6559\u80b2\u90e8",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6700\u9ad8\u4eba\u6c11\u6cd5\u9662",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u4e2d\u592e\u6c14\u8c61\u53f0",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5927\u5b66",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u8054\u5408\u56fd",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u6c14\u8c61\u5c40",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u4e2d\u592e\u7eaa\u59d4",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u65b0\u534e\u7f51",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u515a\u4e2d\u592e",
#                     "value": 9
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 4741472
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u5b89\u90e8",
#                 "\u4eba\u6c11\u68c0\u5bdf\u9662",
#                 "\u56fd\u52a1\u9662",
#                 "\u6e05\u534e\u5927\u5b66",
#                 "\u6559\u80b2\u90e8",
#                 "\u6700\u9ad8\u4eba\u6c11\u6cd5\u9662",
#                 "\u4e2d\u592e\u6c14\u8c61\u53f0",
#                 "\u5317\u4eac\u5927\u5b66",
#                 "\u8054\u5408\u56fd",
#                 "\u6c14\u8c61\u5c40",
#                 "\u4e2d\u592e\u7eaa\u59d4",
#                 "\u65b0\u534e\u7f51",
#                 "\u515a\u4e2d\u592e"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_65fded811ed14a37828af630d92411aa.setOption(option_65fded811ed14a37828af630d92411aa);
#
#     });
# </script>

# %% [markdown]
# ![pie](http://img.blog.csdn.net/20180223211054472?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvc3R5OTQ1/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "11月份出现的高频机构")

# %%
from pyecharts import Pie
deal(res_nz, dic_nz)
output(res_nz)

attr_nz = []
value_nz = []
for nz in res_nz:
    attr_nz.append(nz['words'])
    value_nz.append(nz['nums'])

pie = Pie("11月份高频专有名词", title_pos='center', width=900)
pie.add("商品", attr_nz[2:20], value_nz[2:20], is_random=True, radius=[30, 75], rosetype='area',
        is_legend_show=False, is_label_show=True)
# pie
# Out:
# {'words': '英语', 'nums': 249}
# {'words': '中华', 'nums': 139}
# {'words': '佛教', 'nums': 71}
# {'words': '汉族', 'nums': 62}
# {'words': '扬子', 'nums': 61}
# {'words': '麦当劳', 'nums': 56}
# {'words': '新民', 'nums': 55}
# {'words': '道教', 'nums': 54}
# {'words': '雪豹', 'nums': 53}
# {'words': '熊猫', 'nums': 51}
# {'words': '阿里巴巴', 'nums': 50}
# {'words': '腾讯', 'nums': 50}
# {'words': '八大', 'nums': 42}
# {'words': '通用', 'nums': 40}
# {'words': '新华', 'nums': 38}
# {'words': '苗族', 'nums': 37}
# {'words': '英文', 'nums': 35}
# {'words': '侗族', 'nums': 34}
# {'words': '彝', 'nums': 34}
# {'words': '羌族', 'nums': 33}
# {'words': '中文', 'nums': 33}
# {'words': '东东', 'nums': 33}
# {'words': '红嘴', 'nums': 31}
# {'words': '华文', 'nums': 31}
# {'words': '藏族', 'nums': 31}
# {'words': '清华', 'nums': 30}
# {'words': '吉尼斯', 'nums': 30}
# {'words': '汉语', 'nums': 28}
# {'words': '家乐福', 'nums': 27}
# {'words': '华为', 'nums': 27}
# {'words': '海尔', 'nums': 26}
# {'words': '复旦', 'nums': 25}
# {'words': '波音', 'nums': 24}
# {'words': '奥迪', 'nums': 24}
# {'words': '百度', 'nums': 23}
# {'words': '康师傅', 'nums': 22}
# {'words': '阳光', 'nums': 21}
# {'words': '宝马', 'nums': 21}
# {'words': '南京大屠杀', 'nums': 21}
# {'words': '奔驰', 'nums': 21}

# %% [markdown]
# ![pie](http://img.blog.csdn.net/20180223211111782?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQvc3R5OTQ1/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "11月份高频专有名词")

# %%
from pyecharts import Funnel
deal(res_nz, dic_nz)
output(res_nz)

attr_nz = []
value_nz = []
for nz in res_nz:
    attr_nz.append(nz['words'])
    value_nz.append(nz['nums'])

funnel = Funnel("一月份高频专有名词",  width=600, height=400, title_pos='right')
funnel.add("商品", attr_nz[2:15], value_nz[2:15], legend_orient='vertical', legend_pos='left',
           is_label_show=True, label_pos="inside", label_text_color="#fff")
# funnel
# Out:
# {'words': '英语', 'nums': 249}
# {'words': '中华', 'nums': 139}
# {'words': '佛教', 'nums': 71}
# {'words': '汉族', 'nums': 62}
# {'words': '扬子', 'nums': 61}
# {'words': '麦当劳', 'nums': 56}
# {'words': '新民', 'nums': 55}
# {'words': '道教', 'nums': 54}
# {'words': '雪豹', 'nums': 53}
# {'words': '熊猫', 'nums': 51}
# {'words': '阿里巴巴', 'nums': 50}
# {'words': '腾讯', 'nums': 50}
# {'words': '八大', 'nums': 42}
# {'words': '通用', 'nums': 40}
# {'words': '新华', 'nums': 38}
# {'words': '苗族', 'nums': 37}
# {'words': '英文', 'nums': 35}
# {'words': '侗族', 'nums': 34}
# {'words': '彝', 'nums': 34}
# {'words': '羌族', 'nums': 33}
# {'words': '中文', 'nums': 33}
# {'words': '东东', 'nums': 33}
# {'words': '红嘴', 'nums': 31}
# {'words': '华文', 'nums': 31}
# {'words': '藏族', 'nums': 31}
# {'words': '清华', 'nums': 30}
# {'words': '吉尼斯', 'nums': 30}
# {'words': '汉语', 'nums': 28}
# {'words': '家乐福', 'nums': 27}
# {'words': '华为', 'nums': 27}
# {'words': '海尔', 'nums': 26}
# {'words': '复旦', 'nums': 25}
# {'words': '波音', 'nums': 24}
# {'words': '奥迪', 'nums': 24}
# {'words': '百度', 'nums': 23}
# {'words': '康师傅', 'nums': 22}
# {'words': '阳光', 'nums': 21}
# {'words': '宝马', 'nums': 21}
# {'words': '南京大屠杀', 'nums': 21}
# {'words': '奔驰', 'nums': 21}

# %% [markdown]
# ![bar](https://img-blog.csdn.net/20180401203250518?watermark/2/text/aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L3N0eTk0NQ==/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70 "11月份高频专有名词")
